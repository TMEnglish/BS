# %% [markdown]
# <blockquote cite="comment-259413">
#
# <strong><a href="#comment-259413">EricMH</a></strong>: @TomEnglish it doesn’t seem like any of those points show the EF, CSI or ASC are deprecated.</blockquote>
#
# IDists, as activists in a socio-political movement, never call attention to their own errors. They silently abandon their old claims, and move on to new claims that are fashioned to sound much like the old ones, but are actually quite different.
#
# Are <em>necessity</em>, <em>chance</em>, and <em>design</em> mutually exclusive modes of explanation? The explanatory filter forces a choice of exactly one of the three modes, so if the three modes are not mutually exclusive, then the explanatory filter is invalid. Dembski eventually recognized that <em>necessity</em>, <em>chance</em>, and <em>design</em> are not mutually exclusive, and hence silently abandoned the explanatory filter. When I, under an alias, prompted him to say outright that he was not using the EF anymore, he admitted as much in a comment at Uncommon Descent (which I quoted above) &mdash; and, much to my surprise, briefly explained why. He of course did not admit to error.
#
# (Once I sent an email note to Dembski, explaining something about the NFL theorems that he had misunderstood. His response: OK, but don't expect me to admit that in public.)
#
#
# <blockquote cite="comment-259413">
#
# <strong><a href="#comment-259413">EricMH</a></strong>: If something shows CSI > 1, then it’ll pass the EF. If something has ASC > 1, then it has CSI > 1, and pass the EF.
#
# </blockquote>
#
# What is it with you, that you keep referring to complex specified information (CSI) as a quantity, when it's been explained to you repeatedly that CSI is a category? Seriously, it's high time for you explain yourself.
#
# From Section 3.5 of <em>No Free Lunch</em> (2002):
#
# <blockquote>Think of complex specified information this way. An intelligent agent S identifies a reference class of possibilities $\Omega$ representing a collection of possible events. The event E [&hellip;] is an outcome that occurred via some physical process. The target T [&hellip;] is a pattern identified by the intelligent agent S without recourse to the event E. Since $\Omega$ represents possible events, both T and E denote events. The ordered pair (T,E) now constitutes specified information provided that the event E is included in the event T and provided that T can be identified independently of E (i.e., is detachable from E-see section 2.5). Moreover, if T also has high complexity (or correspondingly small probability-see sections 1.5 and 2.8), then (T,E) constitutes complex specified information or CSI. It follows that for (T,E) to constitute complex specified information is logically equivalent to E satisfying the complexity-specification criterion of section 1.3. Provided E satisfies this criterion, we also say that E exhibits specified complexity. As we saw in chapter 1 and then justified in chapter 2, this means that an intelligent cause was involved in E's causal history.
# </blockquote>
#
# Note well:
#
# 0. <em>Complex specified information</em> is not a synonym for <em>specified complexity.</em>
#
# 1. Dembski uses T to denote both a pattern and an event. Put simply, the event T contains all (and only) elements of $\Omega$ that match the pattern T identified by the intelligent agent S.
#
# 2. What determines whether specified information (T, E) is complex is the probability of event T $\supseteq$ E, not the probability of the physical event E, under the chance hypothesis.
#
# 3. Dembski is wrong in the last sentence in the quotation above, inasmuch as he contradicts Section 2.6, "Sweeping the Field of Chance Hypotheses." What he actually requires for the inference of intelligent cause is that event T in specified information (T, E) be highly improbable under <b>all</b> relevant chance hypotheses, not just one of them.
#
# A way to repair what Dembski has written is to redefine the complexity of $T$ as $\min_i -\!\log_2 P(T|\mathbf{H}_i),$ the minimum log-improbability of $T$ under any of the relevant chance hypotheses $\{\mathbf{H}_i\}.$ However, the point is purely academic, because Dembski silently abandoned complex specified information in 2005.
#
# In "Specification: The Pattern That Signifies Intelligence" (2005), Dembski writes:
#
# <blockquote>[I]f specified complexity is to rule out chance <em>überhaupt</em>, we must have a good grasp of what chance hypotheses would have been operating to produce the observed event $E$ whose chance status is in question. Suppose the relevant collection of chance hypotheses that we have good reason to think were operating if the event $E$ happened by chance is some collection of chance hypotheses $\{\mathbf{H}_i\}_{i \in I}$ indexed by the index set $I.$ Then, to eliminate all these chance hypotheses, [specified complexity] $\chi_i = -\!\log_2[ 10^{120} \cdot \varphi_S(T) \cdot P(T|\mathbf{H}_i)]$ must be greater than 1 for each $\mathbf{H}_i.$
# </blockquote>
#
# <blockquote cite="comment-259413">
#
# <strong>What EricMH might have written if he had taken time to read and to think</strong>: (1) If pattern T has specified complexity 𝝌 > 1, then event T will pass the EF. (2) If a binary string x has ASC > 1, then there is an event T $\ni$ x corresponding to a pattern for which the specified complexity 𝝌 > 1.
#
# </blockquote>
#
# You feel no compunction about tossing off propositions without proofs, and asserting their truth, do you? There is no analog of the <em>specificational resources</em> of pattern $T$ for semiotic agent $S,$ $\varphi_S(T),$ in Dembski's earlier work. So it is hardly obvious how one would deal with $\varphi_S(T)$ in proving the first proposition. Even if you proved the proposition, you would not have vindicated the explanatory filter. Are <em>necessity</em>, <em>chance</em>, and <em>design</em> mutually exclusive modes of explanation? I've put a straight question to you, and if you can't give it a straight answer, as Dembski did, then there's something terribly wrong with you.
